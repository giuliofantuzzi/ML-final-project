# %% [markdown]
# # Text preprocessing
#
# Module of the project about data preparation, more in particular about text analysis.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import emoji
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Import the dataset

# %%
data = pd.read_csv('../../datasets/tweets&users-data.csv')
data.head(5)
# Out:
#                                                 text          username  likes  \
# 0  These Black Pitmasters Are Hustling To Preserv...  @FoodsAreGoodYes      0
# 1                     #ai #food #foodporn #foodlover   @yummy_food_ai_      0
# 2  Chicken Licken Menu  View South african menu; ...     @M14548Mehsud      0
# 3  Pepperoni Pizza 🍕 with Peppers homecookingvsfa...   @homevsfastfood    345
# 4  #Fine #Dining #Dinner #flashback #Focused #Che...       @ChefLondie      0
#
#    comments  retweets  quotes  is-retweet external-link  \
# 0         0         0       0       False           NaN
# 1         0         0       0       False           NaN
# 2         0         0       0       False           NaN
# 3         4        63       1        True           NaN
# 4         0         0       0       False           NaN
#
#                                             pictures videos gifs  \
# 0  ['https://pbs.twimg.com/media/GA0OIEcaYAAOQEF....     []   []
# 1  ['https://pbs.twimg.com/media/GA0ODvvWkAARMm-....     []   []
# 2  ['https://pbs.twimg.com/media/GA0OG2IbIAAVBBw....     []   []
# 3  ['https://pbs.twimg.com/media/GAx6QMZXIAEGXyx....     []   []
# 4  ['https://pbs.twimg.com/media/GA0OBqXXkAA7Vpe....     []   []
#
#                                           user-image  \
# 0  https://pbs.twimg.com/profile_images/170867034...
# 1  https://pbs.twimg.com/profile_images/173305540...
# 2  https://pbs.twimg.com/profile_images/170954226...
# 3  https://pbs.twimg.com/profile_images/129259871...
# 4  https://pbs.twimg.com/profile_images/157618315...
#
#                                             user-bio  \
# 0  I love foods and definitely love writing the f...
# 1                                AI generated images
# 2  🌟 Join us as we take your taste buds on a glob...
# 3  Great food and Recipes #homecookingvsfastfood ...
# 4  Let Us Turn Your Ordinary Event Into An Extrao...
#
#                                         user-website  user-tweets  \
# 0                           https://foodsaregood.com       1029.0
# 1  https://instagram.com/yummy_food_ai_?igshid=Mz...         16.0
# 2                    http://chicken-licken-menu.info       1151.0
# 3                   http://homecookingvsfastfood.com      16136.0
# 4                                                NaN       4790.0
#
#    user-following  user-followers  user-likes  user-media
# 0             1.0             6.0         1.0       861.0
# 1           184.0            33.0       628.0        16.0
# 2            10.0             1.0       102.0       615.0
# 3           550.0         27938.0     11591.0     15625.0
# 4             4.0           118.0     14563.0      2233.0

# %% [markdown]
# Function to replace eventual emojis

# %%
def replace_emojis(text):
    return emoji.demojize(text)

data['text']= data['text'].apply(replace_emojis)
data.head(5)
# Out:
#                                                 text          username  likes  \
# 0  These Black Pitmasters Are Hustling To Preserv...  @FoodsAreGoodYes      0
# 1                     #ai #food #foodporn #foodlover   @yummy_food_ai_      0
# 2  Chicken Licken Menu  View South african menu; ...     @M14548Mehsud      0
# 3  Pepperoni Pizza :pizza: with Peppers homecooki...   @homevsfastfood    345
# 4  #Fine #Dining #Dinner #flashback #Focused #Che...       @ChefLondie      0
#
#    comments  retweets  quotes  is-retweet external-link  \
# 0         0         0       0       False           NaN
# 1         0         0       0       False           NaN
# 2         0         0       0       False           NaN
# 3         4        63       1        True           NaN
# 4         0         0       0       False           NaN
#
#                                             pictures videos gifs  \
# 0  ['https://pbs.twimg.com/media/GA0OIEcaYAAOQEF....     []   []
# 1  ['https://pbs.twimg.com/media/GA0ODvvWkAARMm-....     []   []
# 2  ['https://pbs.twimg.com/media/GA0OG2IbIAAVBBw....     []   []
# 3  ['https://pbs.twimg.com/media/GAx6QMZXIAEGXyx....     []   []
# 4  ['https://pbs.twimg.com/media/GA0OBqXXkAA7Vpe....     []   []
#
#                                           user-image  \
# 0  https://pbs.twimg.com/profile_images/170867034...
# 1  https://pbs.twimg.com/profile_images/173305540...
# 2  https://pbs.twimg.com/profile_images/170954226...
# 3  https://pbs.twimg.com/profile_images/129259871...
# 4  https://pbs.twimg.com/profile_images/157618315...
#
#                                             user-bio  \
# 0  I love foods and definitely love writing the f...
# 1                                AI generated images
# 2  🌟 Join us as we take your taste buds on a glob...
# 3  Great food and Recipes #homecookingvsfastfood ...
# 4  Let Us Turn Your Ordinary Event Into An Extrao...
#
#                                         user-website  user-tweets  \
# 0                           https://foodsaregood.com       1029.0
# 1  https://instagram.com/yummy_food_ai_?igshid=Mz...         16.0
# 2                    http://chicken-licken-menu.info       1151.0
# 3                   http://homecookingvsfastfood.com      16136.0
# 4                                                NaN       4790.0
#
#    user-following  user-followers  user-likes  user-media
# 0             1.0             6.0         1.0       861.0
# 1           184.0            33.0       628.0        16.0
# 2            10.0             1.0       102.0       615.0
# 3           550.0         27938.0     11591.0     15625.0
# 4             4.0           118.0     14563.0      2233.0

# %% [markdown]
# ## Text processing
